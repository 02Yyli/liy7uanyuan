# %%
import pandas as pd
# 创建一个示例 DataFrame
data = {
    'Column1': [1, None, 3, None],
    'Column2': [4, None, None, None],
    'Column3': [7, 8, 9, None],
    'Column4': [7, 8, 9, None]
}
df = pd.DataFrame(data)
print("原始 DataFrame:")
df
# Out:
# 原始 DataFrame:
#    Column1  Column2  Column3  Column4
# 0      1.0      4.0      7.0      7.0
# 1      NaN      NaN      8.0      8.0
# 2      3.0      NaN      9.0      9.0
# 3      NaN      NaN      NaN      NaN

# %%
# 列出所有空白值
print("列出所有空白值：")
df[df.isnull().T.any()]
# Out:
# 列出所有空白值：
#    Column1  Column2  Column3  Column4
# 1      NaN      NaN      8.0      8.0
# 2      3.0      NaN      9.0      9.0
# 3      NaN      NaN      NaN      NaN

# %%
# 删除所有列都是空值的行
df.dropna(how='all', inplace=True)

# 打印处理后的 DataFrame
df
# Out:
#    Column1  Column2  Column3  Column4
# 0      1.0      4.0      7.0      7.0
# 1      NaN      NaN      8.0      8.0
# 2      3.0      NaN      9.0      9.0

# %%
# 将 NaN 值替换为 0
df_filled = df.fillna('空白值')
df_filled
# Out:
#   Column1 Column2  Column3  Column4
# 0     1.0     4.0      7.0      7.0
# 1     空白值     空白值      8.0      8.0
# 2     3.0     空白值      9.0      9.0

# %%
import mytools

# %%
数据表 = mytools.读取SPSS数据文件(R'data\identity.sav',True)

# %%
数据表[数据表.isnull().T.any()]
# Out:
#       问卷编号   调查员    民族 政治面貌   年级 典型中国人  中国人特点    v1    v2     v3  ...  \
# 112  802.0   张玉梅    汉族   团员   大三   一般般   较有特点  完全同意  完全同意     同意  ...
# 223   22.0   黄明军    汉族   群众   大三   一般般    一般般  有点同意  有点同意   有点同意  ...
# 224   25.0   黄明军    汉族   团员   大三   完全是   较无特点  完全同意  完全同意   完全同意  ...
# 397  891.0   张璐婷    回族   团员   大二   可以算  非常有特点  完全同意  完全同意   完全同意  ...
# 489   23.0   黄明军  维吾尔族   党员   大二   不太算    NaN   不同意   不同意    不同意  ...
# 592  227.0    吴桐    汉族   团员   大一   可以算   较有特点  完全同意  完全同意   有点同意  ...
# 806   13.0   黄明军    汉族   团员   大一   完全是   较有特点  有点同意    同意  完全不同意  ...
# 865    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 866    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 867    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 868    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 869    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 870    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 871    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 872    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 873    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 874    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 875    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 876    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 877  870.0  古丽娜孜   NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 878  793.0   李金桃   NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 879    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 880    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 881    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 882    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 883    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 884    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 885    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 886    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 887    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 888    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 889    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 890    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 891    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 892    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 893    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 894    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 895    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 896    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 897    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 898    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 899    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 900    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 901    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 902    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 903    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
# 904    NaN         NaN  NaN  NaN   NaN    NaN   NaN   NaN    NaN  ...
#
#       会隐瞒身份吗  会打多少分    国歌升起   世博会     中国传统文化   发展信心 你会为中国运动员呐喊助威  \
# 112     绝对不会  八十到一百    比较激动  感到自豪       比较肯定  担忧不好说      大多数情况下会
# 223  也许会也许不会  四十到六十    比较激动    一般   古板，跟不上潮流    没信心          不一定
# 224     绝对不会  四十到六十    比较激动   比较好       比较肯定    NaN          NaN
# 397      可能会  六十到八十     NaN  感到自豪  富有内涵，意义深刻   很有信心          肯定会
# 489    很可能不会  四十到六十     没感觉   没感觉   古板，跟不上潮流  担忧不好说          不一定
# 592     绝对不会  八十到一百     没感觉   NaN  富有内涵，意义深刻   很有信心      大多数情况下会
# 806  也许会也许不会   零到二十      一般   比较好       比较肯定  担忧不好说          不一定
# 865      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 866      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 867      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 868      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 869      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 870      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 871      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 872      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 873      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 874      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 875      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 876      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 877      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 878      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 879      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 880      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 881      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 882      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 883      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 884      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 885      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 886      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 887      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 888      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 889      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 890      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 891      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 892      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 893      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 894      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 895      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 896      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 897    很可能不会  四十到六十      一般   比较好       比较肯定  担忧不好说          不一定
# 898      可能会  四十到六十  感到非常激动   比较好  富有内涵，意义深刻  担忧不好说          肯定会
# 899      可能会  六十到八十  感到非常激动  感到自豪  富有内涵，意义深刻   很有信心      大多数情况下会
# 900      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 901      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 902      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 903      NaN    NaN     NaN   NaN        NaN    NaN          NaN
# 904      NaN    NaN     NaN   NaN        NaN    NaN          NaN
#
#     遇到灾难时中国人应该伸出援手 你愿意加入其他国籍吗 中国人要为祖国统一奋斗吗
# 112             赞同      做外籍华人          NaN
# 223            不赞同      做外籍华人          不一定
# 224            NaN        NaN          NaN
# 397            很赞同      做外籍华人          很赞同
# 489            不一定        不加入          不一定
# 592             赞同      做外籍华人          很赞同
# 806            很赞同     毫不犹豫加入           赞同
# 865            NaN        NaN          NaN
# 866            NaN        NaN          NaN
# 867            NaN        NaN          NaN
# 868            NaN        NaN          NaN
# 869            NaN        NaN          NaN
# 870            NaN        NaN          NaN
# 871            NaN        NaN          NaN
# 872            NaN        NaN          NaN
# 873            NaN        NaN          NaN
# 874            NaN        NaN          NaN
# 875            NaN        NaN          NaN
# 876            NaN        NaN          NaN
# 877            NaN        NaN          NaN
# 878            NaN        NaN          NaN
# 879            NaN        NaN          NaN
# 880            NaN        NaN          NaN
# 881            NaN        NaN          NaN
# 882            NaN        NaN          NaN
# 883            NaN        NaN          NaN
# 884            NaN        NaN          NaN
# 885            NaN        NaN          NaN
# 886            NaN        NaN          NaN
# 887            NaN        NaN          NaN
# 888            NaN        NaN          NaN
# 889            NaN        NaN          NaN
# 890            NaN        NaN          NaN
# 891            NaN        NaN          NaN
# 892            NaN        NaN          NaN
# 893            NaN        NaN          NaN
# 894            NaN        NaN          NaN
# 895            NaN        NaN          NaN
# 896            NaN        NaN          NaN
# 897            不一定        不加入          不一定
# 898            不一定         其他           赞同
# 899            不一定         其他           赞同
# 900            NaN        NaN          NaN
# 901            NaN        NaN          NaN
# 902            NaN        NaN          NaN
# 903            NaN        NaN          NaN
# 904            NaN        NaN          NaN
#
# [47 rows x 28 columns]

# %%
数据表.dropna(how="any",inplace=True)

# %%
数据表.年级.value_counts()
# Out:
# 年级
# 大一    305
# 大二    276
# 大三    169
# 大四     94
# 预科     14
# Name: count, dtype: int64

# %%
import pandas as pd

# 示例数据
data = {'value': [10, 12, 12, 13, 12, 11, 10, 29, 30, 11, 10, 100]}
df = pd.DataFrame(data)

# 计算均值和标准差
mean = df['value'].mean()
std = df['value'].std()
condition1 = (df['value'] < mean - 3 * std) | (df['value'] > mean + 3 * std)
# 识别异常值
outliers1 = df[condition1]
print('使用标准差判断的异常值为：',outliers1)

# 计算 IQR
Q1 = df['value'].quantile(0.25)
Q3 = df['value'].quantile(0.75)
IQR = Q3 - Q1

# 识别异常值
outliers2 = df[(df['value'] < Q1 - 1.5 * IQR) | (df['value'] > Q3 + 1.5 * IQR)]
print('使用IQR判断的异常值为：',outliers2)
# Out:
# 使用标准差判断的异常值为：     value
# 11    100
# 使用IQR判断的异常值为：     value
# 7      29
# 8      30
# 11    100

# %%
数据表.drop_duplicates(subset=['问卷编号'],keep='first',inplace=True)

# %%
import pandas as pd
df_movie = pd.read_csv(R'data\movie_data.csv')
df_movie.dtypes
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\l'y'y\Desktop\liy7uanyuan\17-数据清理.ipynb 单元格 12 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/l%27y%27y/Desktop/liy7uanyuan/17-%E6%95%B0%E6%8D%AE%E6%B8%85%E7%90%86.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/l%27y%27y/Desktop/liy7uanyuan/17-%E6%95%B0%E6%8D%AE%E6%B8%85%E7%90%86.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> df_movie = pd.read_csv(R'data\movie_data.csv')
#       <a href='vscode-notebook-cell:/c%3A/Users/l%27y%27y/Desktop/liy7uanyuan/17-%E6%95%B0%E6%8D%AE%E6%B8%85%E7%90%86.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> df_movie.dtypes
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data\\movie_data.csv'

# %%
df_movie.dropna(how='any',inplace=True)
df_movie.astype({"title": "string", "votes": "int64",'genre':"category"}).dtypes

# %%
# 使用query
condition = '会以中国人自豪吗=="会" and 会隐瞒身份吗=="一定会"'

# 取得逻辑不一致数据的序号列表
result = 数据表.query(condition).index
print(result)
# 使用drop函数删除指定
数据表.drop(index=result,inplace=True)
